# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhamoypanja/IPL-2022-Data-Analysis-Project/blob/main/IPL_2022_Data_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Project Submission logo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**IPL-2022 Data Analysis Project**
# #Created By
# ##1. Subhamoy Panja (Enrollment no. EBEON0322584752)
# ##2. Rohini Jagtap (Enrollment no. EBEON0322578023)

# %% [markdown]
# ## Now let’s start this task by importing the necessary Python libraries and the dataset:

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
Ipl_data=pd.read_csv("https://raw.githubusercontent.com/Subhamoypanja/IPL-2022-Data-Analysis-Project-using-Python/main/IPL%202022.csv")  #load the dataset

# %%
Ipl_data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
Ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             46 non-null     int64
#  1   date                 46 non-null     object
#  2   venue                46 non-null     object
#  3   team1                46 non-null     object
#  4   team2                46 non-null     object
#  5   stage                46 non-null     object
#  6   toss_winner          46 non-null     object
#  7   toss_decision        46 non-null     object
#  8   first_ings_score     46 non-null     int64
#  9   first_ings_wkts      46 non-null     int64
#  10  second_ings_score    46 non-null     int64
#  11  second_ings_wkts     46 non-null     int64
#  12  match_winner         46 non-null     object
#  13  won_by               46 non-null     object
#  14  margin               46 non-null     int64
# ...

# %%
Ipl_data.isna()
# Out:
#     match_id   date  venue  team1  team2  stage  toss_winner  toss_decision  \
# 0      False  False  False  False  False  False        False          False
# 1      False  False  False  False  False  False        False          False
# 2      False  False  False  False  False  False        False          False
# 3      False  False  False  False  False  False        False          False
# 4      False  False  False  False  False  False        False          False
# 5      False  False  False  False  False  False        False          False
# 6      False  False  False  False  False  False        False          False
# 7      False  False  False  False  False  False        False          False
# 8      False  False  False  False  False  False        False          False
# 9      False  False  False  False  False  False        False          False
# 10     False  False  False  False  False  False        False          False
# ...

# %%
Ipl_data.tail()
# Out:
#     match_id           date                                         venue  \
# 41        42  April 29,2022  Maharashtra Cricket Association Stadium,Pune
# 42        43  April 30,2022                     Brabourne Stadium, Mumbai
# 43        44  April 30,2022            Dr DY Patil Sports Academy, Mumbai
# 44        45     May 1,2022                      Wankhede Stadium, Mumbai
# 45        46     May 1,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 41   Lucknow     Punjab  Group      Punjab         Field               153
# 42  Banglore    Gujarat  Group    Banglore           Bat               170
# 43    Mumbai  Rajasthan  Group      Mumbai         Field               158
# 44     Delhi    Lucknow  Group     Lucknow           Bat               195
# 45   Chennai  Hyderabad  Group   Hyderabad         Field               202
#
# ...

# %%
Ipl_data.shape
# Out:
# (46, 20)

# %%
Ipl_data.size
# Out:
# 920

# %%
Ipl_data.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %% [markdown]
# ##The dataset contains all the information needed to summarize the story of IPL 2022 so far. So let’s start by looking at the number of matches won by each team in IPL 2022:

# %%
figure = px.bar(Ipl_data, x=Ipl_data["match_winner"],
            title="Number of Matches Won in IPL 2022")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##So, Gujrat is leading the tournament by winning eight matches. It is an achievement as a new team for Gujrat in IPL.

# %%
fig = px.pie(Ipl_data,names="match_winner", title="Number of Matches Won in IPL 2022")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Now see number of toss winner.

# %%
figure = px.bar(Ipl_data, x=Ipl_data["toss_winner"],
            title="Number of tosses Won in IPL 2022")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(Ipl_data,names="toss_winner", title="Number of tosses Won in IPL 2022")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure = px.bar(Ipl_data, x=Ipl_data["top_scorer"],
            title="Top Scorers in IPL 2022")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Here we can see Jos Buttler has been a top scorer in 5 matches. He is looking in great touch.

# %% [markdown]
# ##**Let’s analyze it deeply by including the runs scored by the top scorers:**

# %%
figure = px.bar(Ipl_data, x=Ipl_data["top_scorer"], 
                y = Ipl_data["highscore"], 
                color = Ipl_data["highscore"],
            title="Top Scorers in IPL 2022")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##So Jos Buttler has scored three centuries, and KL Rahul has scored two centuries.

# %% [markdown]
# ##**Now let’s have a look at the most player of the match awards till now in IPL 2022:**

# %%
figure = px.bar(Ipl_data, x = Ipl_data["player_of_the_match"], 
         title="Most Player of the Match Awards")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##So Kuldeep Yadav is leading in the list of players of the match awards with four matches. It is a great tournament for Kuldeep Yadav this year.

# %% [markdown]
# ## **Now let’s have a look at the bowlers with the best bowling figures in most of the matches:**

# %%
figure = px.bar(Ipl_data, x=Ipl_data["best_bowling"],
            title="Best Bowlers in IPL 2022")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##You can see Yuzvendra Chahal having the best bowling figures in four matches. So this is a great tournament for Yuzvendra Chahal this year too.

# %% [markdown]
# #**Now let’s have a look at whether most of the wickets fall while setting the target or while chasing the target:**

# %%
figure = go.Figure()
figure.add_trace(go.Bar(
    x=Ipl_data["venue"],
    y=Ipl_data["first_ings_wkts"],
    name='First Innings Wickets',
    marker_color='darkorange'
))
figure.add_trace(go.Bar(
    x=Ipl_data["venue"],
    y=Ipl_data["second_ings_wkts"],
    name='Second Innings Wickets',
    marker_color='green'
))
figure.update_layout(barmode='group', xaxis_tickangle=-45)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##So in the Wankhede Stadium in Mumbai and MCA Stadium in Pune, most wickets fall while chasing the target. And in the other two stadiums, most wickets fall while setting the target. So this is how you can analyze and summarize the story of IPL 2022 using Python.
